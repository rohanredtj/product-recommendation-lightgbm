# %% [markdown]
# - model 1 training
# - model 1 evaluation
# - model 2 training
# - model 2 evaluation
# - inference script
# - git
# - email

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/prediction/20210822v2_lgb_with_optuna_on_cv_on_auc_on_full_data_normalized_weeks_without_tsfresh_features_and_categorical_original_saved_model_on_heldout_train_format_prediction_trimmed.csv')

# %%
df.head(10)
# Out:
#    codigo_de_cliente fecha_de_visita  codigo_de_producto  \
# 0           94225070      2021-05-31              500040
# 1           94225070      2021-05-31              500574
# 2           94225070      2021-05-31              515512
# 3           94225070      2021-05-31              508588
# 4           94225070      2021-05-31              500176
# 5           94225070      2021-05-31              508524
# 6           94224807      2021-05-31              598795
# 7           94224807      2021-05-31              500115
# 8           94224807      2021-05-31              508720
# 9           94224807      2021-05-31              509546
#
#    prediction probability  predictions  bought_in_the_visit  rank  recomm_qt
# 0                0.407146            0                  1.0     1          6
# 1                0.307235            0                  0.0     2          6
# 2                0.289207            0                  1.0     3          6
# ...
